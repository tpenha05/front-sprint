# %%
import pandas as pd 
from funcoes import *
clube = "Palmeiras"

partidas_teste = { "partidas": [ [ { "adversario": "Bragantino", "clube": "Palmeiras", "data": "21/09/2022", "resultado": "1x1" }, { "adversario": "S\u00e3o Paulo", "clube": "Palmeiras", "data": "21/09/2023", "resultado": "1x8" }, { "adversario": "Bragantino", "clube": "Palmeiras", "data": "21/09/2022", "resultado": "1x1" }, { "adversario": "Bahia", "clube": "Palmeiras", "data": "10/09/2024", "resultado": "0x1" }, { "adversario": "Cruzeiro", "clube": "Palmeiras", "data": "19/11/2024", "resultado": "3x1" }, { "adversario": "Sport", "clube": "Palmeiras", "data": "08/12/2023", "resultado": "4x1" }, { "adversario": "Santos", "clube": "Palmeiras", "data": "01/03/2024", "resultado": "0x2" }, { "adversario": "Fortaleza", "clube": "Palmeiras", "data": "03/08/2024", "resultado": "3x3" }, { "adversario": "S\u00e3o Paulo", "clube": "Palmeiras", "data": "21/09/2023", "resultado": "1x8" } ], [ { "adversario": "Palmeiras", "clube": "Coritiba", "data": "01/09/2024", "resultado": "0x5" }, { "adversario": "Palmeiras", "clube": "Atl\u00e9tico-PR", "data": "09/10/2024", "resultado": "0x3" } ] ] }


df_partidas = pd.DataFrame(partidas_teste["partidas"][0])
df_partidas
# Out:
#    adversario      clube        data resultado
# 0  Bragantino  Palmeiras  21/09/2022       1x1
# 1   São Paulo  Palmeiras  21/09/2023       1x8
# 2  Bragantino  Palmeiras  21/09/2022       1x1
# 3       Bahia  Palmeiras  10/09/2024       0x1
# 4    Cruzeiro  Palmeiras  19/11/2024       3x1
# 5       Sport  Palmeiras  08/12/2023       4x1
# 6      Santos  Palmeiras  01/03/2024       0x2
# 7   Fortaleza  Palmeiras  03/08/2024       3x3
# 8   São Paulo  Palmeiras  21/09/2023       1x8

# %%
df_filtrado = df_partidas[df_partidas['clube'] == clube]
df_filtrado
# Out:
#        clube  adversario        data resultado
# 0  Palmeiras  Bragantino  21/09/2022       1x1
# 1  Palmeiras       Vasco  21/09/2021      33x8
# 2  Palmeiras   Barcelona  22/10/2022       7x1

# %%
dados_rupturas = [{}, {'instante_ruptura': '00:04:57', 'inicio_ruptura': '00:04:56', 'zona': 'Zona 2', 'desfecho': 'Forçou a saída de bola adversária', 'nome_jogador_ruptura': 'Vanderlan'}, {'instante_ruptura': '00:10:12', 'inicio_ruptura': '00:10:12', 'zona': 'Zona 1 - B', 'desfecho': 'Passe não concluído', 'nome_jogador_ruptura': 'Rony'}, {'instante_ruptura': '00:15:02', 'inicio_ruptura': '00:15:01', 'zona': 'Zona 1 - B', 'desfecho': 'Passou a bola', 'nome_jogador_ruptura': 'R. Veiga'}, {'instante_ruptura': '00:51:02', 'inicio_ruptura': '00:51:00', 'zona': 'Zona 2', 'desfecho': 'Passou a bola', 'nome_jogador_ruptura': 'Rony'}, {'instante_ruptura': '00:52:28', 'inicio_ruptura': '00:52:27', 'zona': 'Zona 2', 'desfecho': 'Passou a bola', 'nome_jogador_ruptura': 'Mayke'}, {'instante_ruptura': '00:52:57', 'inicio_ruptura': '00:52:55', 'zona': 'Zona 1 - B', 'desfecho': 'Foi desarmado', 'nome_jogador_ruptura': 'Vanderlan'}, {'instante_ruptura': '01:32:37', 'inicio_ruptura': '01:32:36', 'zona': 'Zona 1 - B', 'desfecho': 'Não recebeu a bola', 'nome_jogador_ruptura': 'Richard Rios'}]
df_rupturas = pd.DataFrame(dados_rupturas)
df_rupturas = df_rupturas.iloc[1:]
df_rupturas.head()
# Out:
#   instante_ruptura inicio_ruptura        zona  \
# 1         00:04:57       00:04:56      Zona 2
# 2         00:10:12       00:10:12  Zona 1 - B
# 3         00:15:02       00:15:01  Zona 1 - B
# 4         00:51:02       00:51:00      Zona 2
# 5         00:52:28       00:52:27      Zona 2
#
#                             desfecho nome_jogador_ruptura
# 1  Forçou a saída de bola adversária            Vanderlan
# 2                Passe não concluído                 Rony
# 3                      Passou a bola             R. Veiga
# 4                      Passou a bola                 Rony
# 5                      Passou a bola                Mayke

# %%
def converter_tempo_para_segundos(tempo_str):
    if not tempo_str:
        return None

    horas, minutos, segundos = map(int, tempo_str.split(':'))

    return horas * 3600 + minutos * 60 + segundos

# %%
lista_tempo_rupturas = []
numero_ruptura = 1
for ruptura_tempo_sec in df_rupturas["inicio_ruptura"]:
    inicio_video = converter_tempo_para_segundos(ruptura_tempo_sec) - 5
    final_video = converter_tempo_para_segundos(ruptura_tempo_sec) +5
    lista_tempo_rupturas.append((inicio_video,final_video))
print(lista_tempo_rupturas)
# Out:
# [(291, 301), (607, 617), (896, 906), (3055, 3065), (3142, 3152), (3170, 3180), (5551, 5561)]

# %%
data_cruzamentos = {
    "time": {
        "5": {
            "id": 5,
            "nome": "Red Bull Bragantino",
            "liga": "Brasileirão Série A",
            "logo": "https://api.deltagoal.ai/5/logo.png",
            "rupturas": [
                {
                    "instante_cruzamento": "00:01:08",
                    "numero_jogadores_time_cruzando": "7, 19, 17",
                    "nome_jogadores_time_cruzando": "Eric Ramires, Sasha, B. Goncalves ",
                    "quantidade_jogadores_time_atacando": 3,
                    "numero_jogadores_time_defendendo": "13, 15, 12, 6, 25",
                    "nome_jogadores_time_defendendo": "Luan, G. Gomez, Mayke, Vanderlan, G. Menino",
                    "quantidade_jogadores_defendendo": 5,
                    "desfecho": "Bem-Sucedido",
                    "zona": "D2.1"
                },
                {
                    "instante_cruzamento": "00:02:47",
                    "numero_jogadores_time_cruzando": "29, 4, 26, 19,17",
                    "nome_jogadores_time_cruzando": "Juninho Capixaba , Natan, E. Santos, Sasha, B. Goncalves ",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "12, 13, 15, 6, 35, 25, 23, 14, 10",
                    "nome_jogadores_time_defendendo": "Mayke, Luan, G. Gomez, Vanderlan, Fabinho, G. Menino, R. Veiga, Artur, Rony",
                    "quantidade_jogadores_defendendo": 9,
                    "desfecho": "Bem-Sucedido",
                    "zona": "D1.1"
                },
                {
                    "instante_cruzamento": "00:09:07",
                    "numero_jogadores_time_cruzando": "17, 29, 19, 26, 4",
                    "nome_jogadores_time_cruzando": "B. Goncalves , Juninho Capixaba , Sasha, E. Santos, Natan",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "12, 13, 15, 6, 25, 35, 7, 10, 14, 23",
                    "nome_jogadores_time_defendendo": "Mayke, Luan, G. Gomez, Vanderlan, G. Menino, Fabinho, Dudu, Rony, Artur, R. Veiga",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Perdido",
                    "zona": "D2.2"
                },
                {
                    "instante_cruzamento": "00:12:21",
                    "numero_jogadores_time_cruzando": "19, 17, 26, 4",
                    "nome_jogadores_time_cruzando": "Sasha, B. Goncalves , E. Santos, Natan",
                    "quantidade_jogadores_time_atacando": 4,
                    "numero_jogadores_time_defendendo": "12, 13, 15, 6, 35, 25, 10",
                    "nome_jogadores_time_defendendo": "Mayke, Luan, G. Gomez, Vanderlan, Fabinho, G. Menino, Rony",
                    "quantidade_jogadores_defendendo": 7,
                    "desfecho": "Perdido",
                    "zona": "E1.1"
                },
                {
                    "instante_cruzamento": "00:21:53",
                    "numero_jogadores_time_cruzando": "26, 4, 17, 19, 34, 29",
                    "nome_jogadores_time_cruzando": "E. Santos, Natan, B. Goncalves , Sasha, J,. Hurtado, Juninho Capixaba ",
                    "quantidade_jogadores_time_atacando": 6,
                    "numero_jogadores_time_defendendo": "12, 13, 15, 6, 35, 25, 23, 7, 10, 14",
                    "nome_jogadores_time_defendendo": "Mayke, Luan, G. Gomez, Vanderlan, Fabinho, G. Menino, R. Veiga, Dudu, Rony, Artur",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bloqueado",
                    "zona": "D2.2"
                },
                {
                    "instante_cruzamento": "00:22:13",
                    "numero_jogadores_time_cruzando": "26, 4, 17, 19, 34, 29",
                    "nome_jogadores_time_cruzando": "E. Santos, Natan, B. Goncalves , Sasha, J,. Hurtado, Juninho Capixaba ",
                    "quantidade_jogadores_time_atacando": 6,
                    "numero_jogadores_time_defendendo": "12, 13, 15, 6, 35, 25, 23, 7, 10, 14",
                    "nome_jogadores_time_defendendo": "Mayke, Luan, G. Gomez, Vanderlan, Fabinho, G. Menino, R. Veiga, Dudu, Rony, Artur",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bloqueado",
                    "zona": "D2.2"
                },
                {
                    "instante_cruzamento": "00:24:11",
                    "numero_jogadores_time_cruzando": "19",
                    "nome_jogadores_time_cruzando": "Sasha",
                    "quantidade_jogadores_time_atacando": 1,
                    "numero_jogadores_time_defendendo": "13, 15",
                    "nome_jogadores_time_defendendo": "Luan, G. Gomez",
                    "quantidade_jogadores_defendendo": 2,
                    "desfecho": "Bem-Sucedido",
                    "zona": "E1.1"
                },
                {
                    "instante_cruzamento": "00:25:50",
                    "numero_jogadores_time_cruzando": "26, 4, 11, 19, 34, 29",
                    "nome_jogadores_time_cruzando": "E. Santos, Natan, Helinho, Sasha, J,. Hurtado, Juninho Capixaba ",
                    "quantidade_jogadores_time_atacando": 6,
                    "numero_jogadores_time_defendendo": "12, 13, 15, 6, 35, 25, 23, 7, 10, 14",
                    "nome_jogadores_time_defendendo": "Mayke, Luan, G. Gomez, Vanderlan, Fabinho, G. Menino, R. Veiga, Dudu, Rony, Artur",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bloqueado",
                    "zona": "E2.2"
                },
                {
                    "instante_cruzamento": "01:20:00",
                    "numero_jogadores_time_cruzando": "2, 19, 9, 16, 28, 26",
                    "nome_jogadores_time_cruzando": "Leo Realpe, Sasha, Alerrandro, Henry, Vitor Hugo, E. Santos",
                    "quantidade_jogadores_time_atacando": 6,
                    "numero_jogadores_time_defendendo": "12, 13, 15, 6, 27, 25, 23, 19, 9, 11",
                    "nome_jogadores_time_defendendo": "Mayke, Luan, G. Gomez, Vanderlan, Richard Rios, G. Menino, R. Veiga, Breno Lopes , Endrick , Tabata",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bloqueado",
                    "zona": "D2.2"
                }
            ]
        },
        "1": {
            "id": 1,
            "nome": "Palmeiras",
            "liga": "Brasileirão Série A",
            "logo": "https://api.deltagoal.ai/1/logo.png",
            "rupturas": [
                {
                    "instante_cruzamento": "00:10:15",
                    "numero_jogadores_time_cruzando": "7",
                    "nome_jogadores_time_cruzando": "Dudu",
                    "quantidade_jogadores_time_atacando": 1,
                    "numero_jogadores_time_defendendo": "7, 34, 26",
                    "nome_jogadores_time_defendendo": "Eric Ramires, J. Hurtado, E. Santos",
                    "quantidade_jogadores_defendendo": 3,
                    "desfecho": "Perdido",
                    "zona": "D2.1"
                },
                {
                    "instante_cruzamento": "00:15:05",
                    "numero_jogadores_time_cruzando": "15, 6, 7, 35",
                    "nome_jogadores_time_cruzando": "G. Gomez, Vanderlan, Dudu, Fabinho",
                    "quantidade_jogadores_time_atacando": 4,
                    "numero_jogadores_time_defendendo": "17, 19, 11, 7, 35, 8, 29, 4, 26, 34",
                    "nome_jogadores_time_defendendo": "B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bem-Sucedido",
                    "zona": "D2.2"
                },
                {
                    "instante_cruzamento": "00:18:26",
                    "numero_jogadores_time_cruzando": "7, 10",
                    "nome_jogadores_time_cruzando": "Dudu, Rony",
                    "quantidade_jogadores_time_atacando": 2,
                    "numero_jogadores_time_defendendo": "4, 26, 34",
                    "nome_jogadores_time_defendendo": "Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 3,
                    "desfecho": "Bloqueado",
                    "zona": "D1.2"
                },
                {
                    "instante_cruzamento": "00:27:08",
                    "numero_jogadores_time_cruzando": "15, 13, 14, 10, 35",
                    "nome_jogadores_time_cruzando": "G. Gomez, Luan, Artur, Rony, Fabinho",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "17, 19, 11, 7, 35, 8, 29, 4, 26, 34",
                    "nome_jogadores_time_defendendo": "B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bem-Sucedido",
                    "zona": "D2.2"
                },
                {
                    "instante_cruzamento": "00:32:16",
                    "numero_jogadores_time_cruzando": "23, 6, 14, 10",
                    "nome_jogadores_time_cruzando": "R. Veiga, Vanderlan, Artur, Rony",
                    "quantidade_jogadores_time_atacando": 4,
                    "numero_jogadores_time_defendendo": "17, 35, 7, 4, 34, 26, 29, ",
                    "nome_jogadores_time_defendendo": "B. Goncalves , Matheus Fernandes, Eric Ramires, Natan, J,. Hurtado, E. Santos, Juninho Capixaba ",
                    "quantidade_jogadores_defendendo": 7,
                    "desfecho": "Bloqueado",
                    "zona": "D2.2"
                },
                {
                    "instante_cruzamento": "00:32:54",
                    "numero_jogadores_time_cruzando": "15, 13, 14, 10, 35",
                    "nome_jogadores_time_cruzando": "G. Gomez, Luan, Artur, Rony, Fabinho",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "17, 19, 11, 7, 35, 8, 29, 4, 26, 34",
                    "nome_jogadores_time_defendendo": "B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Perdido",
                    "zona": "D2.2"
                },
                {
                    "instante_cruzamento": "00:33:34",
                    "numero_jogadores_time_cruzando": "15, 13, 14, 10, 35",
                    "nome_jogadores_time_cruzando": "G. Gomez, Luan, Artur, Rony, Fabinho",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "17, 19, 11, 7, 35, 8, 29, 4, 26, 34",
                    "nome_jogadores_time_defendendo": "B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bloqueado",
                    "zona": "E2.2"
                },
                {
                    "instante_cruzamento": "00:34:16",
                    "numero_jogadores_time_cruzando": "10, 13, 15",
                    "nome_jogadores_time_cruzando": "Rony, Luan, G. Gomez",
                    "quantidade_jogadores_time_atacando": 3,
                    "numero_jogadores_time_defendendo": "8, 4, 29, 26, 19, 11",
                    "nome_jogadores_time_defendendo": "L. Evangelista, Natan, Juninho Capixaba , E. Santos, Sasha, Helinho",
                    "quantidade_jogadores_defendendo": 6,
                    "desfecho": "Bem-Sucedido",
                    "zona": "E1.1"
                },
                {
                    "instante_cruzamento": "00:34:32",
                    "numero_jogadores_time_cruzando": "10, 13, 35, 15, 14",
                    "nome_jogadores_time_cruzando": "Rony, Luan, Fabinho, G. Gomez, Artur",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "11, 4, 34, 29, 26, 35, 8",
                    "nome_jogadores_time_defendendo": "Helinho, Natan, J,. Hurtado, Juninho Capixaba , E. Santos, Matheus Fernandes, L. Evangelista",
                    "quantidade_jogadores_defendendo": 7,
                    "desfecho": "Bloqueado",
                    "zona": "D2.2"
                },
                {
                    "instante_cruzamento": "00:34:46",
                    "numero_jogadores_time_cruzando": "10, 13, 35, 15, 14",
                    "nome_jogadores_time_cruzando": "Rony, Luan, Fabinho, G. Gomez, Artur",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "19, 34, 4, 26, 29, 35, 8",
                    "nome_jogadores_time_defendendo": "Sasha, J,. Hurtado, Natan, E. Santos, Juninho Capixaba , Matheus Fernandes, L. Evangelista",
                    "quantidade_jogadores_defendendo": 7,
                    "desfecho": "Bem-Sucedido",
                    "zona": "D2.2"
                },
                {
                    "instante_cruzamento": "00:50:36",
                    "numero_jogadores_time_cruzando": "10, 13, 35, 15, 14",
                    "nome_jogadores_time_cruzando": "Rony, Luan, Fabinho, G. Gomez, Artur",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "17, 19, 11, 7, 35, 8, 29, 4, 26, 34",
                    "nome_jogadores_time_defendendo": "B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bem-Sucedido",
                    "zona": "E2.2"
                },
                {
                    "instante_cruzamento": "00:54:48",
                    "numero_jogadores_time_cruzando": "10, 13, 35, 15, 14",
                    "nome_jogadores_time_cruzando": "Rony, Luan, Fabinho, G. Gomez, Artur",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "17, 19, 11, 7, 35, 8, 29, 4, 26, 34",
                    "nome_jogadores_time_defendendo": "B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bloqueado",
                    "zona": "E2.2"
                },
                {
                    "instante_cruzamento": "00:55:14",
                    "numero_jogadores_time_cruzando": "10, 13, 35, 15, 14",
                    "nome_jogadores_time_cruzando": "Rony, Luan, Fabinho, G. Gomez, Artur",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "17, 19, 11, 7, 35, 8, 29, 4, 26, 34",
                    "nome_jogadores_time_defendendo": "B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bloqueado",
                    "zona": "E2.2"
                },
                {
                    "instante_cruzamento": "01:01:34",
                    "numero_jogadores_time_cruzando": "10, 13, 35, 15, 14",
                    "nome_jogadores_time_cruzando": "Rony, Luan, Fabinho, G. Gomez, Artur",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "28, 19, 16, 7, 35, 8, 29, 4, 26, 34",
                    "nome_jogadores_time_defendendo": "Vitor Hugo, Sasha, Henry, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bloqueado",
                    "zona": "E2.2"
                },
                {
                    "instante_cruzamento": "01:01:54",
                    "numero_jogadores_time_cruzando": "10, 13, 35, 15, 14",
                    "nome_jogadores_time_cruzando": "Rony, Luan, Fabinho, G. Gomez, Artur",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "28, 19, 16, 7, 35, 8, 29, 4, 26, 34",
                    "nome_jogadores_time_defendendo": "Vitor Hugo, Sasha, Henry, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Perdido",
                    "zona": "E2.2"
                },
                {
                    "instante_cruzamento": "01:06:20",
                    "numero_jogadores_time_cruzando": "9, 13, 35, 15, 14",
                    "nome_jogadores_time_cruzando": "Endrick , Luan, Fabinho, G. Gomez, Artur",
                    "quantidade_jogadores_time_atacando": 5,
                    "numero_jogadores_time_defendendo": "28, 19, 16, 7, 35, 8, 29, 4, 26, 34",
                    "nome_jogadores_time_defendendo": "Vitor Hugo, Sasha, Henry, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bem-Sucedido",
                    "zona": "D2.2"
                },
                {
                    "instante_cruzamento": "01:24:42",
                    "numero_jogadores_time_cruzando": "19",
                    "nome_jogadores_time_cruzando": "Breno Lopes ",
                    "quantidade_jogadores_time_atacando": 1,
                    "numero_jogadores_time_defendendo": "13, 26",
                    "nome_jogadores_time_defendendo": "Aderlan, E. Santos",
                    "quantidade_jogadores_defendendo": 2,
                    "desfecho": "Perdido",
                    "zona": "D3"
                },
                {
                    "instante_cruzamento": "01:33:05",
                    "numero_jogadores_time_cruzando": "11, 13, 15, 18, 9, 27",
                    "nome_jogadores_time_cruzando": "Tabata, Luan, G. Gomez, Flaco Lopez, Endrick , Richard Rios",
                    "quantidade_jogadores_time_atacando": 6,
                    "numero_jogadores_time_defendendo": "26, 29, 35, 7, 19, 2, 9, 13, 16, 28",
                    "nome_jogadores_time_defendendo": "E. Santos, Juninho Capixaba , Matheus Fernandes, Eric Ramires, Sasha, Leo Realpe, Alerrandro, Aderlan, Henry, Vitor Hugo",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bloqueado",
                    "zona": "E2.2"
                },
                {
                    "instante_cruzamento": "01:35:12",
                    "numero_jogadores_time_cruzando": "11, 13, 15, 18, 9, 27",
                    "nome_jogadores_time_cruzando": "Tabata, Luan, G. Gomez, Flaco Lopez, Endrick , Richard Rios",
                    "quantidade_jogadores_time_atacando": 6,
                    "numero_jogadores_time_defendendo": "26, 29, 35, 7, 19, 2, 9, 13, 16, 28",
                    "nome_jogadores_time_defendendo": "E. Santos, Juninho Capixaba , Matheus Fernandes, Eric Ramires, Sasha, Leo Realpe, Alerrandro, Aderlan, Henry, Vitor Hugo",
                    "quantidade_jogadores_defendendo": 10,
                    "desfecho": "Bloqueado",
                    "zona": "E2.2"
                },
                {
                    "instante_cruzamento": "01:35:25",
                    "numero_jogadores_time_cruzando": "11, 13, 15, 9, 19, 18, 27",
                    "nome_jogadores_time_cruzando": "Tabata, Luan, G. Gomez, Endrick , Breno Lopes , Flaco Lopez, Richard Rios",
                    "quantidade_jogadores_time_atacando": 7,
                    "numero_jogadores_time_defendendo": "35, 26, 7, 2, 13, 29",
                    "nome_jogadores_time_defendendo": "Matheus Fernandes, E. Santos, Eric Ramires, Leo Realpe, Aderlan, Juninho Capixaba ",
                    "quantidade_jogadores_defendendo": 6,
                    "desfecho": "Bem-Sucedido",
                    "zona": "D2.1"
                },
                {
                    "instante_cruzamento": "01:36:17",
                    "numero_jogadores_time_cruzando": "9, 18, 19",
                    "nome_jogadores_time_cruzando": "Endrick , Flaco Lopez, Breno Lopes ",
                    "quantidade_jogadores_time_atacando": 3,
                    "numero_jogadores_time_defendendo": "13, 2, 29, 26",
                    "nome_jogadores_time_defendendo": "Aderlan, Leo Realpe, Juninho Capixaba , E. Santos",
                    "quantidade_jogadores_defendendo": 4,
                    "desfecho": "Bloqueado",
                    "zona": "E1.2"
                }
            ]
        }
    }
}

# %%
def trata_video_cruzamentos(data_cruzamentos):

    tempo_video_cruzamentos = {}
    instantes_cruzamentos = []

    for time_id, time_data in data_cruzamentos['time'].items():
        for cruzamento in time_data['rupturas']:
            instantes_cruzamentos.append(cruzamento['instante_cruzamento'])

    numero_cruzamento = 1 
    for tempo in instantes_cruzamentos:
        tempo_segundos = converter_tempo_para_segundos(tempo)
        inicio_video = tempo_segundos -5 
        final_video =  tempo_segundos + 5
        tempo_video_cruzamentos[numero_cruzamento] = (inicio_video,final_video)
        numero_cruzamento += 1
    return tempo_video_cruzamentos
trata_video_cruzamentos(data_cruzamentos)
# Out:
# {1: (63, 73),
#  2: (162, 172),
#  3: (542, 552),
#  4: (736, 746),
#  5: (1308, 1318),
#  6: (1328, 1338),
#  7: (1446, 1456),
#  8: (1545, 1555),
#  9: (4795, 4805),
#  10: (610, 620),
#  11: (900, 910),
#  12: (1101, 1111),
#  13: (1623, 1633),
#  14: (1931, 1941),
#  15: (1969, 1979),
#  16: (2009, 2019),
#  17: (2051, 2061),
#  18: (2067, 2077),
#  19: (2081, 2091),
#  20: (3031, 3041),
#  21: (3283, 3293),
#  22: (3309, 3319),
#  23: (3689, 3699),
#  24: (3709, 3719),
#  25: (3975, 3985),
#  26: (5077, 5087),
#  27: (5580, 5590),
#  28: (5707, 5717),
#  29: (5720, 5730),
#  30: (5772, 5782)}
